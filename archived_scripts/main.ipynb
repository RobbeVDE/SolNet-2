# %%
import pandas as pd
import torch
import os
from matplotlib import pyplot as plt
from main import target_renamer, forecast_maker, data_slicer
from Models.lstm import LSTM
from Data.Featurisation import Featurisation

# %%
lags = 24
forecast_period=24
hidden_size = 100
num_layers = 4
dropout = 0.3
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
month_data = False #1 month of data for testing new code

month_range = pd.date_range("2019-08-01", "2019-08-31 23:00", freq='h', tz="UTC")
source_range = pd.date_range("2016-05-01","2020-07-31 23:00", freq='h', tz="UTC")
target_month = pd.date_range("2020-08-01", "2020-08-31 23:00", freq='h', tz="UTC")
eval_month = pd.date_range("2020-09-01", "2021-07-31 23:00", tz="UTC", freq='h')

# %% [markdown]
# # 0. Data initialization

# %%
openmeteo = pd.read_pickle("Data/openmeteo.pickle")

pvgis = pd.read_pickle('Data/PVGIS.pickle')

CEDA = pd.read_pickle("CEDA_dataNL.pickle")
is_day = pd.read_pickle("Data/is_day.pickle")

meteo2CEDA = {'temperature_2m' :'temperature_1_5m', 
              "relative_humidity_2m":"relative_humidity_1_5m", 
              "pressure_msl": "pressure_MSL",
              "cloud_cover":"total_cloud_amount",
              "shortwave_radiation": "downward_surface_SW_flux",
              "diffuse_radiation":"diffuse_surface_SW_flux",
              "direct_normal_irradiance":"direct_surface_SW_flux",
              "wind_speed_10m": "wind_speed_10m",
              "wind_direction_10m": "wind_direction_10m"
              }
openmeteo = openmeteo.rename(columns=meteo2CEDA)

# %%
openmeteo
# Out:
#                            temperature_1_5m  relative_humidity_1_5m  \
# date
# 2016-05-01 00:00:00+00:00        276.830505               89.285660
# 2016-05-01 01:00:00+00:00        276.330505               90.854256
# 2016-05-01 02:00:00+00:00        275.980499               91.482162
# 2016-05-01 03:00:00+00:00        275.780487               91.797310
# 2016-05-01 04:00:00+00:00        275.730499               91.794098
# ...                                     ...                     ...
# 2021-12-31 19:00:00+00:00        284.830505               93.275887
# 2021-12-31 20:00:00+00:00        284.580505               95.145828
# 2021-12-31 21:00:00+00:00        284.880493               94.213600
# 2021-12-31 22:00:00+00:00        284.830505               94.211380
# 2021-12-31 23:00:00+00:00        284.380493               95.774307
#
#                            pressure_MSL  total_cloud_amount  wind_speed_10m  \
# date
# 2016-05-01 00:00:00+00:00   1025.300049               0.000        3.101613
# 2016-05-01 01:00:00+00:00   1025.800049               0.000        2.507987
# 2016-05-01 02:00:00+00:00   1026.199951               0.021        2.800000
# 2016-05-01 03:00:00+00:00   1026.199951               0.102        3.301515
# 2016-05-01 04:00:00+00:00   1026.599976               0.180        2.630589
# ...                                 ...                 ...             ...
# 2021-12-31 19:00:00+00:00   1019.500000               0.459        5.693857
# 2021-12-31 20:00:00+00:00   1020.400024               1.000        6.307139
# 2021-12-31 21:00:00+00:00   1021.200012               1.000        6.293648
# 2021-12-31 22:00:00+00:00   1021.599976               0.876        5.478138
# 2021-12-31 23:00:00+00:00   1022.000000               0.546        5.412024
#
#                            wind_direction_10m  downward_surface_SW_flux  \
# date
# 2016-05-01 00:00:00+00:00          358.152435                       0.0
# 2016-05-01 01:00:00+00:00            4.573841                       0.0
# 2016-05-01 02:00:00+00:00          360.000000                       0.0
# 2016-05-01 03:00:00+00:00            1.735665                       0.0
# 2016-05-01 04:00:00+00:00            8.746089                      21.0
# ...                                       ...                       ...
# 2021-12-31 19:00:00+00:00          239.381470                       0.0
# 2021-12-31 20:00:00+00:00          244.653870                       0.0
# 2021-12-31 21:00:00+00:00          252.428650                       0.0
# 2021-12-31 22:00:00+00:00          248.586960                       0.0
# 2021-12-31 23:00:00+00:00          242.488083                       0.0
#
#                            diffuse_surface_SW_flux  direct_surface_SW_flux
# date
# 2016-05-01 00:00:00+00:00                      0.0                0.000000
# 2016-05-01 01:00:00+00:00                      0.0                0.000000
# 2016-05-01 02:00:00+00:00                      0.0                0.000000
# 2016-05-01 03:00:00+00:00                      0.0                0.000000
# 2016-05-01 04:00:00+00:00                     12.0               97.652107
# ...                                            ...                     ...
# 2021-12-31 19:00:00+00:00                      0.0                0.000000
# 2021-12-31 20:00:00+00:00                      0.0                0.000000
# 2021-12-31 21:00:00+00:00                      0.0                0.000000
# 2021-12-31 22:00:00+00:00                      0.0                0.000000
# 2021-12-31 23:00:00+00:00                      0.0                0.000000
#
# [49704 rows x 9 columns]

# %%
installation_id = "3437BD60"
prodNL = pd.read_parquet('Data/production.parquet', engine='pyarrow')
metadata = pd.read_csv("Data/installations Netherlands.csv", sep=';')
metadata = metadata.set_index('id')
metadata_id = metadata.loc[installation_id]
tilt = metadata_id["Tilt"]
peakPower = metadata_id["Watt Peak"]
azimuth = metadata_id["Orientation"]
latitude = metadata_id["Latitude"]
longitude = metadata_id["Longitude"]
power = prodNL.loc[installation_id]
power = target_renamer(power, 'watt')
power = power.resample('h').sum()/4
power = power.tz_localize('UTC')
#power.index = power.index.shift(periods=2)
print(latitude, longitude, peakPower, azimuth, tilt)
plt.plot(power)
print(power)
# Out:
# 52.0499 5.07391 3100 5 33
#                                P
# timestamp
# 2019-01-10 15:00:00+00:00    0.0
# 2019-01-10 16:00:00+00:00    0.0
# 2019-01-10 17:00:00+00:00    0.0
# 2019-01-10 18:00:00+00:00    0.0
# 2019-01-10 19:00:00+00:00    0.0
# ...                          ...
# 2021-08-09 16:00:00+00:00  954.0
# 2021-08-09 17:00:00+00:00  337.0
# 2021-08-09 18:00:00+00:00  100.0
# 2021-08-09 19:00:00+00:00    5.0
# 2021-08-09 20:00:00+00:00    0.0
#
# [22614 rows x 1 columns]

# %%
#target and evaluation data will stay the same most probablyy
target_CEDA = data_slicer(CEDA, target_month)
target_power = data_slicer(power, target_month)
eval_CEDA = data_slicer(CEDA, eval_month)
eval_power = data_slicer(power, eval_month)

#TARGET DATASET
data = pd.merge(target_power, target_CEDA, left_index=True, right_index=True, how='inner')
data = pd.merge(data, is_day, right_index=True, left_index=True)

data = [data] # Put it in a list to work with featurisation object

#2. Featurise data & ready for training & testing 7
data = Featurisation(data)
data.data = data.cyclic_features()
data.data = data.add_shift('P')
data.data = data.cyclic_angle('wind_direction_10m')
data.data = data.PoA(latitude, longitude, tilt, azimuth)
data.data = data.remove_outliers(tolerance=50)

target_dataset = data.data[0]

## EVALUATION DATASET
data = pd.merge(eval_power, eval_CEDA, left_index=True, right_index=True, how='inner')
data = pd.merge(data, is_day, right_index=True, left_index=True)
data = [data] # Put it in a list to work with featurisation object

#2. Featurise data & ready for training & testing 7
data = Featurisation(data)
data.data = data.cyclic_features()
data.data = data.add_shift('P')
data.data = data.cyclic_angle('wind_direction_10m')
data.data = data.PoA(latitude, longitude, tilt, azimuth)
data.data = data.remove_outliers(tolerance=50)


eval_dataset = data.data[0]
print(eval_dataset)
# Out:
#                               P  temperature_1_5m  relative_humidity_1_5m  \
# 2020-09-01 00:00:00+00:00   0.0        283.621826               91.747078
# 2020-09-01 01:00:00+00:00   0.0        283.621826               91.747078
# 2020-09-01 02:00:00+00:00   0.0        283.178223               93.100021
# 2020-09-01 03:00:00+00:00   0.0        282.962402               94.491180
# 2020-09-01 04:00:00+00:00   0.0        283.078369               93.862251
# ...                         ...               ...                     ...
# 2021-07-31 19:00:00+00:00  27.0        291.173584               77.048073
# 2021-07-31 20:00:00+00:00   0.0        290.445068               80.800293
# 2021-07-31 21:00:00+00:00   0.0        289.452637               85.674126
# 2021-07-31 22:00:00+00:00   0.0        289.241455               85.317856
# 2021-07-31 23:00:00+00:00   0.0        288.321045               92.201263
#
#                            total_cloud_amount  diffuse_surface_SW_flux  \
# 2020-09-01 00:00:00+00:00            0.625000                      0.0
# 2020-09-01 01:00:00+00:00            0.625000                      0.0
# 2020-09-01 02:00:00+00:00            0.593750                      0.0
# 2020-09-01 03:00:00+00:00            0.687500                      0.0
# 2020-09-01 04:00:00+00:00            0.718750                      0.0
# ...                                       ...                      ...
# 2021-07-31 19:00:00+00:00            0.984375                     18.0
# 2021-07-31 20:00:00+00:00            1.000000                      0.0
# 2021-07-31 21:00:00+00:00            0.984375                      0.0
# 2021-07-31 22:00:00+00:00            0.718750                      0.0
# 2021-07-31 23:00:00+00:00            0.468750                      0.0
#
#                            direct_surface_SW_flux  downward_surface_SW_flux  \
# 2020-09-01 00:00:00+00:00               -0.000000                       0.0
# 2020-09-01 01:00:00+00:00               -0.000000                       0.0
# 2020-09-01 02:00:00+00:00               -0.000000                       0.0
# 2020-09-01 03:00:00+00:00               -0.000000                       0.0
# 2020-09-01 04:00:00+00:00               -0.000000                       0.0
# ...                                           ...                       ...
# 2021-07-31 19:00:00+00:00               31.858725                       7.0
# 2021-07-31 20:00:00+00:00               -0.000000                       0.0
# 2021-07-31 21:00:00+00:00               -0.000000                       0.0
# 2021-07-31 22:00:00+00:00               -0.000000                       0.0
# 2021-07-31 23:00:00+00:00               -0.000000                       0.0
#
#                            pressure_MSL  wind_speed_10m  wind_direction_10m  \
# 2020-09-01 00:00:00+00:00   102072.4375        1.682858          -44.774261
# 2020-09-01 01:00:00+00:00   102072.4375        1.682858          -44.774261
# 2020-09-01 02:00:00+00:00   102088.8750        1.776363          -43.774616
# 2020-09-01 03:00:00+00:00   102050.3750        1.465025          -51.692028
# 2020-09-01 04:00:00+00:00   102028.8125        1.316142          -64.431190
# ...                                 ...             ...                 ...
# 2021-07-31 19:00:00+00:00   100829.5625        3.557596          -15.495971
# 2021-07-31 20:00:00+00:00   100848.3750        2.017651            8.951687
# 2021-07-31 21:00:00+00:00   100868.5000        2.789327           34.100925
# 2021-07-31 22:00:00+00:00   100871.8750        2.954950           36.541679
# 2021-07-31 23:00:00+00:00   100874.8125        2.576219           48.770100
#
#                            is_day  hour_sin  hour_cos  month_sin  \
# 2020-09-01 00:00:00+00:00     0.0  0.000000  1.000000       -1.0
# 2020-09-01 01:00:00+00:00     0.0  0.258819  0.965926       -1.0
# 2020-09-01 02:00:00+00:00     0.0  0.500000  0.866025       -1.0
# 2020-09-01 03:00:00+00:00     0.0  0.707107  0.707107       -1.0
# 2020-09-01 04:00:00+00:00     0.0  0.866025  0.500000       -1.0
# ...                           ...       ...       ...        ...
# 2021-07-31 19:00:00+00:00     1.0 -0.965926  0.258819       -0.5
# 2021-07-31 20:00:00+00:00     0.0 -0.866025  0.500000       -0.5
# 2021-07-31 21:00:00+00:00     0.0 -0.707107  0.707107       -0.5
# 2021-07-31 22:00:00+00:00     0.0 -0.500000  0.866025       -0.5
# 2021-07-31 23:00:00+00:00     0.0 -0.258819  0.965926       -0.5
#
#                               month_cos  P_24h_shift  wind_direction_10m_cos  \
# 2020-09-01 00:00:00+00:00 -1.836970e-16         0.13                0.709887
# 2020-09-01 01:00:00+00:00 -1.836970e-16         0.13                0.709887
# 2020-09-01 02:00:00+00:00 -1.836970e-16         0.13                0.722067
# 2020-09-01 03:00:00+00:00 -1.836970e-16         0.13                0.619888
# 2020-09-01 04:00:00+00:00 -1.836970e-16         0.13                0.431595
# ...                                 ...          ...                     ...
# 2021-07-31 19:00:00+00:00 -8.660254e-01        15.00                0.963649
# 2021-07-31 20:00:00+00:00 -8.660254e-01         0.00                0.987820
# 2021-07-31 21:00:00+00:00 -8.660254e-01         0.00                0.828051
# 2021-07-31 22:00:00+00:00 -8.660254e-01         0.00                0.803424
# 2021-07-31 23:00:00+00:00 -8.660254e-01         0.00                0.659082
#
#                            wind_direction_10m_sin        PoA
# 2020-09-01 00:00:00+00:00               -0.704315   0.000000
# 2020-09-01 01:00:00+00:00               -0.704315   0.000000
# 2020-09-01 02:00:00+00:00               -0.691823   0.000000
# 2020-09-01 03:00:00+00:00               -0.784690   0.000000
# 2020-09-01 04:00:00+00:00               -0.902068   0.000000
# ...                                           ...        ...
# 2021-07-31 19:00:00+00:00               -0.267171  15.326519
# 2021-07-31 20:00:00+00:00                0.155602   0.000000
# 2021-07-31 21:00:00+00:00                0.560652   0.000000
# 2021-07-31 22:00:00+00:00                0.595407   0.000000
# 2021-07-31 23:00:00+00:00                0.752071   0.000000
#
# [7992 rows x 19 columns]

# %% [markdown]
# # 1. NWP data

# %% [markdown]
# Case study 1:
# |   | Source   | Target |
# |---|----------|--------|
# | X | CEDA | CEDA|
# | Y | PVGIS    | Prod NL|

# %%
from Data.Featurisation import Featurisation

source_pvgis = data_slicer(pvgis, source_range)
source_CEDA = data_slicer(CEDA, source_range)


data = pd.merge(source_pvgis, source_CEDA, left_index=True, right_index=True)
data = pd.merge(data, is_day, right_index=True, left_index=True)

data = [data] # Put it in a list to work with featurisation object

#2. Featurise data & ready for training & testing 7
data = Featurisation(data)
data.data = data.cyclic_features()
data.data = data.add_shift('P')
data.data = data.cyclic_angle('wind_direction_10m')
data.data = data.PoA(latitude, longitude, tilt, azimuth)
data.data = data.remove_outliers(tolerance=50)
data.data = data.inverter_limit(2500)

source_dataset = data.data[0]
if month_data:
    source_dataset = source_dataset[source_dataset.index.isin(month_range)]

min = source_dataset.min(axis=0).to_dict()
max = source_dataset.max(axis=0).to_dict()

# %%
print((source_dataset.corr()-eval_dataset.corr()).loc['P'])
print(source_dataset.corr().loc['P'])
print(eval_dataset.corr().loc['P'])
# Out:
# P                           0.000000
# temperature_1_5m            0.043071
# relative_humidity_1_5m      0.007609
# total_cloud_amount          0.031052
# diffuse_surface_SW_flux    -0.020873
# direct_surface_SW_flux     -0.006795
# downward_surface_SW_flux   -0.016421
# pressure_MSL               -0.069379
# wind_speed_10m              0.048052
# wind_direction_10m          0.037912
# is_day                      0.010451
# hour_sin                   -0.010427
# hour_cos                   -0.039175
# month_sin                  -0.032210
# month_cos                   0.042760
# P_24h_shift                -0.027713
# wind_direction_10m_cos     -0.019216
# wind_direction_10m_sin      0.044333
# PoA                        -0.006183
# Name: P, dtype: float64
# P                           1.000000
# temperature_1_5m            0.400402
# relative_humidity_1_5m     -0.627485
# total_cloud_amount         -0.176575
# diffuse_surface_SW_flux     0.720924
# direct_surface_SW_flux      0.787163
# downward_surface_SW_flux    0.889610
# pressure_MSL                0.107022
# wind_speed_10m              0.054817
# wind_direction_10m         -0.067368
# is_day                      0.577515
# hour_sin                    0.078589
# hour_cos                   -0.665151
# month_sin                   0.008661
# month_cos                  -0.255033
# P_24h_shift                 0.758264
# wind_direction_10m_cos     -0.067939
# wind_direction_10m_sin     -0.094259
# PoA                         0.899150
# Name: P, dtype: float64
# P                           1.000000
# temperature_1_5m            0.357331
# relative_humidity_1_5m     -0.635095
# total_cloud_amount         -0.207627
# diffuse_surface_SW_flux     0.741797
# direct_surface_SW_flux      0.793958
# downward_surface_SW_flux    0.906032
# pressure_MSL                0.176401
# wind_speed_10m              0.006765
# wind_direction_10m         -0.105280
# is_day                      0.567064
# hour_sin                    0.089016
# hour_cos                   -0.625977
# month_sin                   0.040871
# month_cos                  -0.297792
# P_24h_shift                 0.785977
# wind_direction_10m_cos     -0.048723
# wind_direction_10m_sin     -0.138592
# PoA                         0.905333
# Name: P, dtype: float64

# %%
features = list(source_dataset.columns)
features = ['temperature_1_5m', 'relative_humidity_1_5m', 'diffuse_surface_SW_flux', 'direct_surface_SW_flux', 'downward_surface_SW_flux', 'PoA', 'P_24h_shift', "is_day"]
print(features)
# Out:
# ['temperature_1_5m', 'relative_humidity_1_5m', 'diffuse_surface_SW_flux', 'direct_surface_SW_flux', 'downward_surface_SW_flux', 'PoA', 'P_24h_shift', 'is_day']

# %%
source_state_dict, target_state_dict, y_truth, y_forecast = forecast_maker(source_dataset, target_dataset, features, eval_dataset, [min,max])
# Out:
# Shape of data:  torch.Size([1138, 24, 8]) torch.Size([285, 24, 8]) torch.Size([1138, 24, 1]) torch.Size([285, 24, 1])
# Step 0: Average train loss: 0.0732 | Average test loss: 0.0368
# Step 5: Average train loss: 0.0129 | Average test loss: 0.0128
# Step 10: Average train loss: 0.0130 | Average test loss: 0.0143
# Step 15: Average train loss: 0.0119 | Average test loss: 0.0115
# Step 20: Average train loss: 0.0112 | Average test loss: 0.0112
# Step 25: Average train loss: 0.0108 | Average test loss: 0.0114
# Step 30: Average train loss: 0.0107 | Average test loss: 0.0098
# Step 35: Average train loss: 0.0099 | Average test loss: 0.0092
# Step 40: Average train loss: 0.0102 | Average test loss: 0.0090
# Step 45: Average train loss: 0.0102 | Average test loss: 0.0103
# Step 50: Average train loss: 0.0101 | Average test loss: 0.0102
# Step 55: Average train loss: 0.0105 | Average test loss: 0.0102
# Step 60: Average train loss: 0.0096 | Average test loss: 0.0091
# Step 65: Average train loss: 0.0098 | Average test loss: 0.0093
# Step 70: Average train loss: 0.0097 | Average test loss: 0.0088
# Step 75: Average train loss: 0.0095 | Average test loss: 0.0095
# Step 80: Average train loss: 0.0094 | Average test loss: 0.0098
# Step 85: Average train loss: 0.0103 | Average test loss: 0.0098
# Step 90: Average train loss: 0.0093 | Average test loss: 0.0092
# Step 95: Average train loss: 0.0096 | Average test loss: 0.0094
# Best Epoch: 70
# Shape of data:  torch.Size([24, 24, 8]) torch.Size([6, 24, 8]) torch.Size([24, 24, 1]) torch.Size([6, 24, 1])
# Step 0: Average train loss: 0.0087 | Average test loss: 0.0127
# Step 5: Average train loss: 0.0085 | Average test loss: 0.0127
# Step 10: Average train loss: 0.0083 | Average test loss: 0.0126
# Step 15: Average train loss: 0.0082 | Average test loss: 0.0126
# Step 20: Average train loss: 0.0080 | Average test loss: 0.0126
# Step 25: Average train loss: 0.0079 | Average test loss: 0.0126
# Step 30: Average train loss: 0.0078 | Average test loss: 0.0126
# Step 35: Average train loss: 0.0077 | Average test loss: 0.0126
# Step 40: Average train loss: 0.0076 | Average test loss: 0.0125
# Step 45: Average train loss: 0.0075 | Average test loss: 0.0125
# Step 50: Average train loss: 0.0074 | Average test loss: 0.0125
# Step 55: Average train loss: 0.0074 | Average test loss: 0.0125
# Step 60: Average train loss: 0.0073 | Average test loss: 0.0125
# Step 65: Average train loss: 0.0073 | Average test loss: 0.0125
# Step 70: Average train loss: 0.0072 | Average test loss: 0.0125
# Step 75: Average train loss: 0.0072 | Average test loss: 0.0125
# Step 80: Average train loss: 0.0071 | Average test loss: 0.0126
# Step 85: Average train loss: 0.0071 | Average test loss: 0.0126
# Step 90: Average train loss: 0.0070 | Average test loss: 0.0126
# Step 95: Average train loss: 0.0070 | Average test loss: 0.0126
# Best Epoch: 55
#            RMSE      Var(x)      Var(y)  Corr  Bias  Conditional bias 1  \
# Metrics 217.092 336,628.143 320,289.064 0.929 2.187          47,126.406
#
#          Resolution  Conditional bias 2  Discrimination
# Metrics 336,583.375          28,465.160     336,588.094

# %%
plt.figure()

day = 80
plt.plot(y_forecast[(24*day):(24*day)+71], color='red')
plt.plot(y_truth[(24*day):(24*day)+71], color='blue')

# %%
plt.scatter(y_forecast, y_truth, s=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.scatter(y_forecast, y_truth, s=5)
#
# NameError: name 'plt' is not defined
